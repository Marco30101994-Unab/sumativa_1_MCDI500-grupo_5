# %% [markdown]
# # Fase 1 Definición del problema y entorno reproducible
#
# **Asignatura:** MCDI500 Programación para la Ciencia de Datos
# **Evaluación:** Sumativa 1
# **Grupo:** 5
# **Integrantes:** Marco Álvarez Araya, Lishy Cortes Astudillo, María Fassler Neumann y Ricardo Jaramillo Pulgar
#
# ## Propósito del notebook
#
# Este notebook corresponde a la Fase 1 de la Evaluación Sumativa 1. Su propósito es documentar la definición del problema y verificar que el entorno de trabajo sea reproducible para todos los integrantes del grupo.
#
# En esta fase se verificará el intérprete de Python, el entorno virtual, las librerías instaladas, la estructura del repositorio y el estado inicial del control de versiones.
#
# ## Alcance de la Fase 1
#
# La temática aún se encuentra en su búsquedas de acuerdo a lo solicitado por el profesor.
