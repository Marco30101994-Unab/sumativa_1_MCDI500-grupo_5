# %% [markdown]
# # Fase 1 Definición del problema y entorno reproducible
#
# **Asignatura:** MCDI500 Programación para la Ciencia de Datos
# **Evaluación:** Sumativa 1
# **Grupo:** 5
# **Integrantes:** Marco Álvarez Araya, María Fassler Neumann y Ricardo Jaramillo Pulgar

# %% [markdown]
# ## 1 Propósito del notebook

# %% [markdown]
# ## 2 Contextualización del Proyecto
#
# El proyecto aborda el análisis de los permisos activos de uso de calles en la ciudad de San Francisco, utilizando el conjunto de datos público disponible a través de DataSF. El conjunto de datos contiene información asociada a permisos de uso del espacio
# público, el cual permite analizar características relacionadas con el tipo de permiso, su ubicación territorial y otros atributos disponibles. El análisis busca identificar patrones y factores asociados con la duración de estos permisos, mediante técnicas de exploración, procesamiento y análisis de datos.

# %% [markdown]
# ## 3 Definición de la Problemática
#
# El uso temporal de los espacios públicos mediante permisos de uso de calles
# genera registros con distintas características, tipos de permisos, ubicaciones y
# duraciones.
#
# No obstante, la existencia de múltiples atributos en el conjunto de datos dificulta
# identificar qué características presentan una mayor asociación con la duración de
# los permisos activos.
#
# Por esa razón, se plantea analizar el conjunto de datos con el propósito de
# identificar patrones y asociaciones entre la duración de los permisos y sus
# principales características.

# %% [markdown]
# ## 4 Pregunta de Investigación
# **¿Qué factores se asocian con la duración de los permisos activos de uso de calles
# en San Francisco, considerando el tipo de permiso, la ubicación territorial y las
# demás características disponibles en el conjunto de datos?**

# %% [markdown]
# ## 5. Objetivo general
# Analizar los factores asociados a la duración de los permisos activos de uso de
# calles en San Francisco, mediante técnicas de exploración, procesamiento y análisis
# de datos, considerando el tipo de permiso, la ubicación territorial y las demás
# características disponibles en el conjunto de datos.

# %% [markdown]
# ## 6. Objetivos específicos
# 1. Caracterizar los permisos activos de uso de calles según sus principales
#    atributos, incluyendo tipo, ubicación y duración.
#
# 2. Explorar y depurar el conjunto de datos, identificando valores faltantes,
#    registros duplicados, inconsistencias y posibles valores atípicos.
#
# 3. Analizar la asociación entre la duración de los permisos y variables como
#    el tipo de permiso, la ubicación territorial y otras características
#    relevantes disponibles en el conjunto de datos.
#
# 4. Identificar patrones y diferencias en la duración de los permisos mediante
#    técnicas de análisis y visualización de datos.

# %% [markdown]
# ## 7. Alcance del Proyecto
# El proyecto se enfocará en el análisis de los permisos activos de uso de calles
# contenidos en el conjunto de datos seleccionado.
#
# El análisis considerará las variables disponibles en la fuente de datos que
# resulten pertinentes para estudiar la duración de los permisos, incluyendo
# características relacionadas con su tipo, ubicación y temporalidad.
#
# El proyecto contempla las etapas de obtención, exploración, limpieza,
# transformación, validación y análisis de los datos.
#
# No se buscará establecer relaciones causales entre las variables, sino identificar
# asociaciones y patrones presentes en los datos.

# %% [markdown]
# ## 8. Limitaciones del Proyecto
# El proyecto puede presenta algunas limitaciones que deben ser consideradas al momento de interpretar los resultados obtenidos.
#
# - Datos faltantes o inconsistentes: durante las etapas de exploración y preparación podrían identificarse valores faltantes, duplicados, inconsistencias o registros que requieran tratamiento. Estas situaciones pueden limitar el uso de determinadas variables o afectar los análisis posteriores.
#
# - Dependencia de la fuente de datos: el análisis estará limitado a la información disponible en el conjunto de datos público de DataSF. Por lo tanto, las conclusiones dependerán de las variables registradas y de la calidad de la información proporcionada por la fuente.
#
# - Variables disponibles: el estudio solo podrá considerar factores que estén registrados en el conjunto de datos. Pueden existir características relevantes para la duración de los permisos que no estén disponibles o no puedan ser incorporadas al análisis.
#
# Estas limitaciones serán consideradas durante las etapas de preparación, análisis e interpretación de los resultados, asegurando que las conclusiones sean coherentes con la información disponible y con el alcance definido para el proyecto.

# %% [markdown]
# ## 9 Supuestos del Análisis
# Para el desarrollo del análisis se consideran los siguientes supuestos:
#
# - Los registros disponibles representan permisos activos según la definición
#   establecida por la fuente de datos.
#
# - Las fechas y demás variables temporales disponibles permiten determinar o
#   estimar la duración de los permisos.
#
# - Las variables de ubicación disponibles permiten realizar un análisis territorial
#   de los permisos.
#
# - Los datos pueden contener valores faltantes, inconsistencias o valores atípicos,
#   los cuales serán identificados y tratados durante la etapa de procesamiento.
#
# - Las conclusiones estarán limitadas a la información contenida en el conjunto
#   de datos y al período representado por este.

# %% [markdown]
# ## 10 Fuente y descripción del conjunto de datos

# %% [markdown]
# ### 10.1 Fuente, enlace y licencia

# %% [markdown]
# ### 10.2 Justificación de la selección del dataset

# %% [markdown]
# ## 11 Validación inicial del conjunto de datos

# %% [markdown]
# ## 12 Reconomimiento inicial y diccionario preliminar de variables

# %% [markdown]
# ## 13 Entorno de trabajo reproducible

# %% [markdown]
# ### 13.1 Versión de Python y Kernel utlizado

# %% [markdown]
# ### 13.2 Librerías y dependencias

# %% [markdown]
# ## 14 Estructura del repositorio y uso de rutas relativas

# %% [markdown]
# ## 15 Módulo reutilizable inicial

# %% [markdown]
# ## 16 Control de versiones y colaboración en Github

# %% [markdown]
# ## 17 Verificación final de la fase 1
